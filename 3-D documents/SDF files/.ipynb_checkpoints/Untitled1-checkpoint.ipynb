# %%
from thermo.chemical import Chemical
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
import statsmodels.api as sma

matplotlib.style.use('ggplot')

import csv
import cirpy
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
comps = open('database.csv','r')
readCSV = csv.reader(comps, delimiter=',')
i=0
for row in readCSV:
    i+=1
    d=[row[0],row[1],row[2],row[3]]
    print (d)
print(i)
comps.close()
# Out:
# ['2,4-Dichlorophenyl 3-methoxy-4-nitrophenyl ether', 'C13H9Cl2NO4', '9.55E-07', '314.13']
# ['Niflumic acid', 'C13H9F3N2O2', '3.03E-04', '282.22']
# ['Phenanthridine', 'C13H9N', '1.67E-03', '179.22']
# ['Acridine', 'C13H9N', '3.20E-04', '179.22']
# ['2-Hydroxyacridine', 'C13H9NO', '2.00E-05', '195.22']
# ['p-Biphenyl isothiocyanate', 'C13H9NS', '1.40E-05', '211.29']
# ['m-Biphenyl isothiocyanate', 'C13H9NS', '3.00E-05', '211.29']
# ['Fluorene', 'C13H10', '1.01E-05', '166.22']
# ['Leptophos', 'C13H10BrCl2O2PS', '5.82E-06', '412.08']
# ['Leptophos oxon', 'C13H10BrCl2O3P', '8.59E-06', '396.01']
# ['N-( p-Chlorophenyl)-o-hydroxybenzamide', 'C13H10ClNO2', '4.89E-08', '247.68']
# ['2,4,-Dichloro-6-benzyl-phenol', 'C13H10Cl2O', '2.30E-05', '253.13']
# ['Dichlorophen', 'C13H10Cl2O2', '1.12E-04', '269.13']
# ['Benodanil', 'C13H10INO', '6.19E-05', '323.14']
# ['9-Aminoacridine', 'C13H10N2', '6.00E-05', '194.24']
# ['4-Aminoacridine', 'C13H10N2', '7.00E-05', '194.24']
# ...

# %%
data=open('database.csv','r')
f=open('fail.csv','w')
readCSV = csv.reader(data, delimiter=',')
r = csv.writer(f)
r.writerow(['Name','COMPOUND','SOLUBILITY','MW'])
for row in readCSV:
    try:
        cirpy.download(row[0],row[0]+'.sdf','sdf')
    except Exception as e:
                                        try: c = open(row[0]+'.sdf','r')
                                        except:
                                                print(row[0])
                                                r.writerow(row[0])
    pass
data.close()
f.close()
# Out:
# Pyrolan
# 1-Phenyl-3-met
# 2,4-Octadione
# Valerylacetone

# %%
cirpy.download("6H-Dipyrido[3,2-b:2',3'-e][1,4]diazepin-6-one, 2-chloro-11-ethyl-5,11-dihydro-5-methyl-","2-Chloro-11-ethyl-5-methyl-5,11-dihydro-6H-dipyrido[3,2-b.sdf",'sdf')
